# %% [markdown]
# ## Data Visualization

# %%
# import libraries
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns

# %%
#git the data from Seaborn 
diamonds=sns.load_dataset('diamonds')
diamonds.head(20)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
sns.relplot( x='carat', y='price', hue=diamonds.carat.tolist(), data=diamonds)

# %%
 data_grouped_by_depth= diamonds.groupby('depth', as_index=False).sum()
data_grouped_by_depth
# Out:
#      depth  carat  table  price      x      y     z
# 0     43.0   2.09  113.0   8412  12.85  12.82  8.09
# 1     44.0   1.00   53.0   4032   6.31   6.24  4.12
# 2     50.8   1.43   60.0   6727   7.73   7.25  3.93
# 3     51.0   0.30   67.0    945   4.67   4.62  2.37
# 4     52.2   0.70   65.0   1895   6.04   5.99  3.14
# ..     ...    ...    ...    ...    ...    ...   ...
# 179   72.2   0.96   56.0   2438   6.01   5.81  4.28
# 180   72.9   0.90   54.0   2691   5.74   5.67  4.16
# 181   73.6   0.99   60.0   1789   6.01   5.80  4.35
# 182   78.2   1.03   54.0   1262   5.72   5.59  4.42
# 183   79.0   1.00  146.0   5158  10.42  10.36  8.18
#
# [184 rows x 7 columns]

# %%
visual_data= sns.barplot(x="carat", y="price", data=data_grouped_by_depth, ci=None)

# %%
sns.barplot(x='carat', y='price', data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# ### for sure when carat increase the price increase

# %%
sns.pairplot(diamonds[['catat','price','table','depth','new_deaths','new_tests','total_tests']])
